# %%
print("Hello, World! This is a simple Python script.")
# Out:
# Hello, World! This is a simple Python script.

# %%
an_apple = 27
an_example = 42

b = [1, 2, 3, 4, 5]

import datetime

datetime.MAXYEAR
print(datetime.MINYEAR)
# Out:
# 1

# %%
b?
# Out:
# Type:        list
# String form: [1, 2, 3, 4, 5]
# Length:      5
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
a = 4.5; b = 6

print(f"a is of type {type(a)} and b is of type {type(b)}")
# Out:
# a is of type <class 'float'> and b is of type <class 'int'>

# %%
tup = 4, 5, 6

tup
tuple([1, 2, 3, 4])

tup = tuple('string')

print(tup)
# Out:
# ('s', 't', 'r', 'i', 'n', 'g')
